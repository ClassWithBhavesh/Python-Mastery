# %%
# Operators in Python -
# operators - symbol which will perform certain operations
# operands  - operands are the value on which we will perform operations
# operation - is a task or a process in which something is done

# Arithmatic
# Assignment
# Comparion
# Logical

# Arithmatic Operators : +, -, *, /, **, //, %
# num1 = 25
# num2 = 21
# print(num1 + num2)
# tSum = num1 + num2
# print("Sum of num1 and num2 : ", tSum)


# num1 = 25
# num2 = 21
# tSum = num1 - num2
# print("Sub of num1 and num2 : ", tSum)


# num1 = 25
# num2 = 21
# tSum = num1 * num2
# print("Multiplication of num1 and num2 : ", tSum)


# num1 = 25
# num2 = 5
# tSum = num1 / num2          # it will perform division on the operands and return only Decimal Values
# print("Division of num1 and num2 : ", tSum)


# num1 = 25
# num2 = 5
# tSum = num1 // num2         # it will perform division on the operands and return only Integer Values
# print("Floor Division of num1 and num2 : ", tSum)


# num1 = 25
# num2 = 2
# tSum = num1 ** num2
# print("Exponential of num1 over num2 : ", tSum)


# num1 = 25
# num2 = 26
# tSum = num1 % num2            # Remainder of the division performed
# print("Modulus of num1 and num2 : ", tSum)

# %%
# Asignment Operators : +=, -=, *=, /=, =, //=, **=, %=
# num1 = 5
# num2 = 10

# num1 += num2        # num1 = num1 + num2
# print("update by += : ", num1)
# print("Value of num2 : ", num2)

# num2 -= num1          # num2 = num2 - num1
# print("update by -= : ", num2)

# num2 *= num1            # num2 = num2 * num1
# print("update by *= : ", num2)

# num2 /= num1              # num2 = num2 / num1
# print("update by /= : ", num2)

# num1 //= num2               # num1 = num1 // num2
# print("update by //= : ", num1)

# num2 **= num1                 # num2 = num2 ** num1
# print("update by **= : ", num2)

# num1 %= num2                   # num1 = num1 % num2
# print("update by %= : ", num1)

# %%
# Comparison Operators - >, <, >=, <=, ==, != (always return a boolean value)

# num1 = 5
# num2 = 10

# print(num1 > num2)
# print(num1 < num2)
# print(num2 >= num1)
# print(num2 <= num1)
# print(num2 == num1)
# print(num2 != num1)

# %%
# Logical Operators - and | or | not
# - used when there are 2 or more conditions

# num1 = 10
# num2 = 20
# num3 = 30

# print(num2 >= num2 and num2 < num3)
# print(num2 > num2 or num2 < num3)
# print(not(num2 >= num2 and num2 < num3))
# print(not(num2 > num2 or num2 > num3))

# %%
# Membership Operators - used to check weather the value exists in the Data Structure or not.
# - not in
# - in

# li1 = [[1,2],4,5]
# li2 = [1,2]

# print(li2 in li1)


# li1 = [[[1,2], 4 ,5], 5,23]
# li2 = [[1,2, 4, 5]]

# print(li2 not in li1)
# print(li2 in li1)
# len(li1)
# print(len(li1[0]))
# print(li1[0])
# print(li1[1])
# print(li1[2])

# %%
# Identity Operators - check whether the given operand's value and memory location is same or not
# - is
# - is not

# li1 = [[[1,2], 4, 5]]
# li2 = [[1,2], 4, 5]
# li3 = li1

# print(li2 is li1)
# print(li2 is li3)
# print(li3 is li1)



# person1 = "Anushka1"
# person2 = "Priya"
# person3 = person2
# person4 = "Anushka1"

# print(person1 is person4)
# print(person2 is person3)
# print(person2 is not person4)
# print(person2 is not person1)

# %%
# Bitwise Opoerators - AND (&),  OR (|), XOR (^)

# # 1. AND (&)
# num1 = 8
# num2 = 10

# print(num1 & num2)

# # 2. OR (|)
# num1 = 8
# num2 = 10

# print(num1 | num2)

# # 3. XOR (^)
# num1 = 8
# num2 = 10

# print(num1 ^ num2)



num1 = 14
num2 = 5

print(num1 & num2)
print(num1 | num2)
print(num1 ^ num2)
# Out:
# 4
# 15
# 11
