# %%
# Conditonal Statements in Python
# when on the behalf of any condition is we want to perform some operations than we will use conditional statement
# if | else | elif


# age = 25

# if age < 18:
#   print("not eligible")
# else:
#   print("eligible")



# lightValue = "Red"

# if lightValue == "Red":
#   print("Stop Your vehicle!")
# elif lightValue == "Yellow":
#   print("Start Your Vehicle")
# elif lightValue == "Green":
#   print("You Can Gooo!")
# else:
#   print("Apni Suvidha Anusar Gaadi Nikale!")
