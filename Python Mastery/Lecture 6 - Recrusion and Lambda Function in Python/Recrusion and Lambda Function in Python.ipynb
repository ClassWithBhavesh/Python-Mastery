# %% [markdown]
# ### ***Resursion In Python - Recursive Function In Python***

# %%
# Recursion in Python - recursive function - when a function (sum()) call it self in the same sum() function then it will be a
# recursive function and the phenomenon or the concept is known as Recursion!
# to perform a function repeatedly (Redundancy increase hoti hai!)
# Redundancy - repeatetion

# def sum(a, b):
#   num_sum = a + b
#   if num_sum > 500:
#     print(num_sum)
#     print("Recursive function stopped!")
#   else:
#     print("Recursive function continued!")
#     sum(a + 10, b + 10)

# a = 45
# b = 52

# sum(a,b)
# sum(45, 96)



# def fact(n):
#   if n == 1:
#     print(n)
#     return n
#   else:
#     print(n)
#     return n * fact(n - 1)

# factorial =  fact(5)
# print(factorial)

# %% [markdown]
# ### ***Lambda Function In Python***

# %%
# lambda function in python is a short-small one-line anonymous function in python

# num = 96
# new_num = lambda n: n + 10
# # new_num = lambda n,m,o,p: n + 10
# print(num)
# print(new_num(num))


li = [10,20,50,30,60,90,24]


# filter(func, data_structure on which filtering has to be performed)
# filtered_li = filter(lambda x: x >= 30, li)
# print(filtered_li)
# filtered_li = list(filter(lambda x: x >= 30, li))
# print(filtered_li)

mapped_li = tuple(map(lambda v: v + 10, li))
print(mapped_li)



# Curiosity Corner - can a Lambda Function be a Recursive Function?
# Out:
# (20, 30, 60, 40, 70, 100, 34)
