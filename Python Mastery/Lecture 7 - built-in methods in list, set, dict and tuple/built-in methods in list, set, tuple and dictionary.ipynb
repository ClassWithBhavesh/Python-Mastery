# %% [markdown]
# ### ***Pre-Built Methods or Functions in Python***

# %% [markdown]
# # ***List Methods -***

# %%
# 1. .sort() - it will sort each element of list (default - ascending and if reverse argument is used then descending)
# li = [1, 8,2, 7, 9, 3,4]    # ascedning order sorted
# print(f"Before Sorting - {li}")
# li.sort()                    # Ascending order sorting
# print(f"After Sorting - {li}")
# li.sort(reverse=True)        # Descending order sorting
# print(f"After Sorting - {li}")



# IoT_Temp_d1 = [21.6, 54.3, 32.5, 21.3, 23.4]

# print("before sorting : ", IoT_Temp_d1)
# IoT_Temp_d1.sort()
# print("after sorting : ",IoT_Temp_d1)

# IoT_Temp_d1.sort(reverse=True)
# print("after reverse sorting : ",IoT_Temp_d1)




# 2. .append()
# li = [21.6, 54.3, 32.5, 21.3, 23.4]
# print("Before Appending : ", li)

# another_value = 24.6
# li.append(another_value)
# li.append(24.6)
# another_list = [24.6, 23.8, 27.5]
# li.append(another_list)
# print("After Appending : ", li)

# IoT_Temp_d1.append(24.6, 25.3, 21.5) # using this code we'll encounter with an typeError coz .append method will expect only single argument



# 3. .extend() - expand karna list ko!
# li = [21.6, 54.3, 32.5, 21.3, 23.4]
# print("Before Extending : ", li)

# another_list = [24.6, 23.5, 25.1]
# li.extend([24.6])
# li.extend(another_list)
# print("After Extending : ", li)
# another_list.extend(li)
# print("After Extending : ", another_list)





# 4. .insert() - it will insert the value on our desired index value
# IoT_Temp_d1 = [21.6, 54.3, 32.5, 21.3, 23.4]
# print("Before Inserting : ", IoT_Temp_d1)

# IoT_Temp_d1.insert(index, value)
# IoT_Temp_d1.insert(2, 24.3)
# IoT_Temp_d1.insert(2, [24.3, 21.6, 23.9])
# print("After Inserting : ", IoT_Temp_d1)




# 5. .remove(value) - it will remove the argumented value from the list
# IoT_Temp_d1 = [21.6, 54.3, [24.3, 21.6, 23.9], 32.5, 21.3, 23.4]
# print("Before Removing : ", IoT_Temp_d1)

# IoT_Temp_d1.remove(value)
# IoT_Temp_d1.remove(21.3)
# IoT_Temp_d1.remove(21.3, 21.6)
# IoT_Temp_d1.remove([24.3, 21.6, 23.9])
# print("After Removing : ", IoT_Temp_d1)




# 6. .pop(index) - it will remove the argumented value from the list on the basis of indexes (default it will remove the end value)
# IoT_Temp_d1 = [21.6, 54.3, 32.5, 21.3, 23.4]
# print("Before Poping : ", IoT_Temp_d1)

# IoT_Temp_d1.pop(index=?)
# IoT_Temp_d1.pop(2)
# IoT_Temp_d1.pop()
# IoT_Temp_d1.remove(21.3)
# IoT_Temp_d1.insert(2, [24.3, 21.6, 23.9])
# print("After Poping : ", IoT_Temp_d1)





# 7. .clear() - it will clear the list (all elements will be removed and return an empty list)
# IoT_Temp_d1 = [21.6, 54.3, 32.5, 21.3, 23.4]
# print("Before Clearing : ", IoT_Temp_d1)

# IoT_Temp_d1.clear()
# print("After Clearing : ", IoT_Temp_d1)





# 8. index(value, start=7, end=10)
# IoT_Temp_d1 = [21.6, 54.3, 32.5, 23.4, 54.3, 21.3, 54.3, 23.4]
# print("Before Indexing : ", IoT_Temp_d1)

# print("index of 54.3 - ", IoT_Temp_d1.index(54.3))
# print("index of 23.4 - ", IoT_Temp_d1.index(23.4))
# print("index of 54.3 - ", IoT_Temp_d1.index(54.3, 2, 46))
# print("After Indexing : ", IoT_Temp_d1)




# 9. .reverse()
# IoT_Temp_d1 = [21.6, 54.3, 32.5, 54.3, 21.3, 54.3, 23.4]

# print("Before Reversing : ", IoT_Temp_d1)
# IoT_Temp_d1.reverse()
# print("After Reversing : ", IoT_Temp_d1)




# 10. .copy() - It will create a copy of a list
# IoT_Temp_d1 = [21.6, 54.3, 32.5, 54.3, 21.3, 54.3, 23.4]
# print("Before Copying : ", IoT_Temp_d1)

# copied_list = IoT_Temp_d1.copy()
# print("After Copying : ", copied_list)
# copied_list.pop(3)
# print("Before Copying : ", IoT_Temp_d1)
# print("After Copying : ", copied_list)

# %% [markdown]
# ### ***Tuple Methods -***

# %%
# tuple Methods - due to immutability tuple doesn't have bunch of methods. it has only two methods which are in the following -
# 1. .count()
# 2. .index()


# 1. .count(Value)
# bikeTuple = ("Splendar", "CD-Deluxe", "Freedom", "CD-Deluxe", "Boxer", "CD-Deluxe", "RX-110")
# print(bikeTuple.count("CD-Deluxe"))
# print(bikeTuple.count("Splendar"))


# 2. .index(Value)
# akProOrders = ("Micchhar","Sev", "Micchar", "Aloo Bhujiya", "Micchar", "Chips")
# print(akProOrders.index("Micchar"))

# %% [markdown]
# ## ***Set Methods -***

# %%
# 1..add(element)
# ex-1
# customers = {101, 102, 103}
# print(customers)
# customers.add(104)
# print(customers)

# ex-2
# categories = {"Electronics", "Clothing"}
# print(categories)
# categories.add("Furniture")
# print(categories)



# 2. setName.clear()
# tags = {"Sale", "Trending", "Refurbished"}
# print(tags)
# tags.clear()
# print(tags)


# build_set = {}
# print(type(build_set))   # return empty dictionary

# build_set = set()
# print(type(build_set))   # return empty set




# 3. .copy()
# s1 = {1, 2, 3}
# s2 = s1.copy()
# print(s2)
# print(s1)

# s1.add("KuchBhi")
# print(s2)
# print(s1)


# Shallow Copy - a ditto copy of the first set but dependent on the first set
# Deep Copy    - a ditto copy of the first set but in-dependent of the first set



# 4. .difference(newSet)
# setA = {"Mobile", "Laptop", "Tablet"}
# print(setA)
# setB = {"Laptop", "Camera"}
# print(setB)
# # print("different value of set A", setA.difference(setB))
# print("different value of set B", setB.difference(setA))



# 5. .difference_update(newSet) - it will remove the founded value
# setA = {"Mobile", "Laptop", "Tablet"}
# print(setA)
# setB = {"Laptop", "Camera"}
# print(setB)

# anotherSet = setA.difference_update(setB)
# print("Another Set - ", anotherSet)
# print("different value of set A", setA.difference_update(setB))
# print("different value of set B", setB.difference_update(setA))
# print(setA)
# print(setB)

# A = {1,2,3,4}
# B = {3,4}
# A.difference_update(B)
# print(A)


# 6. discard(element) - it will remove the element by the correct argument
# cart = {"Shoes","Watch","Belt"}
# print(cart)
# unavailable = "Belt"
# cart.discard(unavailable)
# print(cart)
# cart.discard("Watch")
# print(cart)



# 7. intersection(other_set) - it will return the common value between the two sets
# skills = {"Python","SQL", "Go"}
# print(skills)
# job = {"Python","Java", "Kotlin", "Go"}
# print(job)
# print(skills.intersection(job))


# 8. intersection_update(other_set) - it will return the common value between the two sets
# skills = {"Python","SQL","Excel"}
# print(skills)
# required = {"Python","SQL"}
# print(required)
# print(skills.intersection_update(required))


# A = {1,2,3}
# B = {2,3}
# A.intersection_update(B)
# print(A)


# 9. .isdisjoint(other_set)
# A = {1,2}
# B = {3,4}
# print(A.isdisjoint(B))

# A = {1,2, 3, 4}
# B = {3,4}
# print(A.isdisjoint(B))


# employees = {"Rahul","Amit", "Manoj"}
# guests = {"Suresh","Manoj"}
# print(employees.isdisjoint(guests))




# 10. .subset(other_set) -
# req = {"Python", "JavaScript"}
# dev = {"Python","SQL", "JavaScript", "PhP"}
# print("Subset Checks - ")
# print(req.issubset(dev))
# print(dev.issubset(req))



# 11. .superset(other_set) -
# req = {"Python", "JavaScript"}
# dev = {"Python","SQL", "JavaScript", "PhP"}
# print("Superset Checks - ")
# print(req.issuperset(dev))
# print(dev.issuperset(req))



# 12. .pop() -
# s = {1,2,3}
# print(s)
# print(s.pop())
# print(s)



# 13. remove(Element)
# s = {1,2,3}
# print(s)
# s.remove(3)  # simply remove the element
# s.remove(7)  # throws an error
# print(s)



# 14. symmetric_difference
# A = {1,2}
# B = {2,3}
# print(A)
# print(B)
# print(A.symmetric_difference(B))
# print(A)
# print(B)





# 15. .symmetric_difference_update(other_set)
# A = {1,2, 3}
# B = {2,3, 1}
# print(A.symmetric_difference_update(B))

# x = {"A","B"}
# y = {"B","C"}
# print(x)
# print(y)
# print(x.symmetric_difference_update(y))
# print(x)
# print(y)



# 16. union(otdet_set)
# skills = {"Python", "Java"}
# extra = {"SQL","Java"}
# new_set = skills.union(extra)
# print(new_set)




# 17. .update(Other_set) - '+='
# skills = {"Python"}
# print(skills)
# skills.update({"SQL","Java"})
# print(skills)


# A = {1,2}
# print(A)
# B = {3,4}
# A.update(B)
# print(A)

# %% [markdown]
# # ***Dict Methods -***

# %%
# 1. clear()
# cart = {"item1": 299, "item2": 499}
# print(cart)
# cart.clear()
# print(cart)


# 2. copy()
# config = {"theme": "dark", "lang": "en"}
# print(config)
# backup = config.copy()
# print(backup)
# backup.clear()
# print(config)
# print(backup)


# 3. fromkeys(sequence, value=None)
# students = ["A", "B", "C"]
# marks = dict.fromkeys(students, 0)
# print(marks)
# students = [1, 2, 3]
# marks = dict.fromkeys(students, 0)
# print(marks)
# students = [1.1, 2.1, 3.3]
# marks = dict.fromkeys(students, "Kuch Or")
# print(marks)


# 4. get(key, default=None)
# emp = {"name": "Rohan", "salary": 50000}
# print(emp.get("salary"))
# print(emp.get("name"))
# print(emp.get("username"))



# 5. items()
d = {"a": 1, "b": 2, "c": 3}
# print(d.items())
# print(list(d.items()))
# print(tuple(d.items()))
# print(dict(d.items()))
# print(str(d.items()))

# for k,v in d.items():
#     print(k, v)


# 6. keys()
# product = {"name": "Laptop", "price": 50000, "color": "mat black", "name": "mobile"}
# print(product.keys())
# print(list(product.keys()))
# print(set(product.keys()))


# 7. value()
# student = {"name": "Neha", "marks": 92}
# print(student.values())


# 8. pop(key, default="Kuch nahi hota default isme")
# inventory = {"Laptop": 10, "Mobile": 20}
# print(inventory.pop("laptop"))
# print(inventory.pop("Value Deni Padegi"))
# print(inventory.pop())
# inventory


# 9. popitem()
# actions = {"login": True, "clicked": "home"}
# print(actions.popitem())
# actions


# 10. setdefault(key, default)
# user = {
#     "dict1" : {"name": "Amit", "city": "Dehradun"},
#     "dict2" : {"name": "Amit", "city": "Bhopal"},
#     "dict3" : {"name": "Amit"}
#         }
# print(user)
# user.setdefault("city", "Indore")
# print(user)
# user["dict3"].setdefault("city", "Indore")
# print(user)


# 11. update(other_dict)
# profile = {"name": "Rohan"}
# print(profile)
# profile.update({"age": 24})
# print(profile)


# d1 = {"a": 1}
# d2 = {"b": 2}
# print(d1)
# d1.update(d2)
# print(d1)
# print(d2)
