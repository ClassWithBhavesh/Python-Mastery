# %%
# Function in python -
# - is a block of code which will perform certain tasks or operation
# - it is reusable
# - their is two step process to execute a function -
    # 1. Declare a function
    # 2. calling a function
# - types of functions - officially -
    # - Standard (user-defined) function
    # - Pre-built function (built-in function)
    # - Recursive function (originated by the concept of recursion)
    # - Lambda function
# - types of functions - according to Bhavesh Sir
    # 1. Standard function - default function
    # 2. parametric function - we can pass some values on which function will execute
    # 3. function with return value - and the end we will return the execution within the function itself

# function's standard syntax -
# def FuncName():       # function declaration
#   function body
#   function body
#   function body
#   function body
#   print(sum)

# FuncName()            # function calling




# num1 = 14
# num2 = 58
# result = num1 + num2
# print(result)

# num1 = 234
# num2 = 458
# result = num1 + num2
# print(result)

# num1 = 23
# num2 = 48
# result = num1 + num2
# print(result)


# Standard function - non-parametric function bhi keh sakte ho!
# def sumFunc():        # declaration of a function
#   num1 = 76
#   num2 = 94
#   result = num1 + num2
#   print(result)

# sumFunc()             # calling of a function
# sumFunc()             # calling of a function
# sumFunc()             # calling of a function
# sumFunc()             # calling of a function
# sumFunc()             # calling of a function



# parametric function -

# parameters - values which we will pass at the time of function declaration
# def sumFunc(num1, num2):    # function declaration - num1, num2 values di jayengi
#   result = num1 + num2
#   # print("sum of", num1 , "and", num2,  "is -", result)
#   print(f"sum of {num1} and {num2} is - {result}")

# sumFunc(10,20)                   #  10 ----> num1      &      20 ----> num2
# sumFunc(40,50)                   #  40 ----> num1      &      50 ----> num2
# sumFunc(54,98)                   #  54 ----> num1      &      98 ----> num2
# sumFunc(51,26)                   #  51 ----> num1      &      26 ----> num2
# sumFunc(74,82)                   #  74 ----> num1      &      82 ----> num2
# arguments - values which we will pass at the time of function calling


# function with return value -
# function for obtained marks -

# student_name = input("Enter Student's Name - ")
# maths_marks = int(input("enter marks for maths - "))
# sst_marks = int(input("enter marks for sst - "))
# science_marks = int(input("enter marks for science - "))
# english_marks = int(input("enter marks for english - "))
# hindi_marks = int(input("enter marks for hindi - "))

# def obt_marks(maths, sst, science, hin, en):
#   obt_Marks = maths + sst + science + hin + en
#   return obt_Marks

# st_obt_marks = obt_marks(maths_marks,sst_marks,science_marks,english_marks,hindi_marks)
# tMarks = 500
# # function for student's percentage -
# def percentage(ob_marks, tMarks):
#   per = ob_marks/tMarks * 100
#   return per

# st_percentage = percentage(st_obt_marks, tMarks)

# # function for result printing -
# def resultPrinting(obtained_marks, student_percentage):
#   if student_percentage < 100 and student_percentage >= 80:
#     print(f"{student_name} has scored {obtained_marks} marks and the percentage are {student_percentage}% and secured 'A grade'")
#   elif student_percentage < 80 and student_percentage >= 60:
#     print(f"{student_name} has scored {obtained_marks} marks and the percentage are {student_percentage}% and secured 'B grade'")
#   elif student_percentage < 60 and student_percentage >= 40:
#     print(f"{student_name} has scored {obtained_marks} marks and the percentage are {student_percentage}% and secured 'C grade'")
#   elif student_percentage < 40 and student_percentage >= 33:
#     print(f"{student_name} has scored {obtained_marks} marks and the percentage are {student_percentage}% and secured 'D grade'")
#   else:
#     print(f"{student_name} has scored {obtained_marks} marks and the percentage are {student_percentage}% and secured 'F grade'")


# resultPrinting(st_obt_marks, st_percentage)
# Out:
# Enter Student's Name - Siddharth Solanki
# enter marks for maths - 70
# enter marks for sst - 38
# enter marks for science - 80
# enter marks for english - 65
# enter marks for hindi - 82
# Siddharth Solanki has scored 335 marks and the percentage are 67.0% and secured 'B grade'
