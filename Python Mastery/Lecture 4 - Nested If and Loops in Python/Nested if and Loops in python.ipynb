# %%
# num = int(input("Enter a num : "))

# if num%2 == 0:
#   print("Even number!")
# else:
#   print("Odd number!")




# year = int(input("Enter a years b/w 1900-2050 - "))

# if year%4 == 0 and year%400 == 0:
#   print(year, " - Leap Year")
# else:
#   print(year, " - Not A Leap Year")

# %%
# # NESTED IF -
# # you've have to grab 3 inputs from users, compare them and arrange them in both -
# # 1. ascending order
# # 2. descending order

# num1 = 12
# num2 = 13
# num3 = 9

# if num1 < num2 and num1 < num3:
#   if num2 < num3:
#     print(num1, " - " , num2, " - ", num3)
#   else:
#     print(num1, " - " , num3, " - ", num2)
# elif num2 < num3 and num2 < num1:
#   if num3 < num1:
#     print(num2, " - " , num3, " - ", num1)
#   else:
#     print(num2, " - " , num1, " - ", num3)
# elif num3 < num1 and num3 < num2:
#   if num1 < num2:
#     print(num3, " - " , num1, " - ", num2)
#   else:
#     print(num3, " - " , num2, " - ", num1)
# else:
#   print("All are equal")

# %%
# LOOPS IN PYTHON - while | for
# to execute a loop -
# 1. variable declaration
# 2. variable condition applying (to manipulate loop - where to stop and run the loop)
# 3. variable increment or decrement

# lap = 0

# while lap < 11:
#   # if lap == 8:
#   #   break       # if our requirements are filled than we'd break the loop and if not than continue untill loop terminate's itself
#   print(lap)
#   lap += 1



# for loop -
# for lap in range(startPoint, endPoint, Skip / Steps)

# for lap in range(0, 11):
#   print(lap)


# for evenNum in range(1, 100, 2):
#   newNum = evenNum * 10
#   if(newNum < 500):
#     print(newNum)
#   else:
#     break
