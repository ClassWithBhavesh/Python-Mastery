# %%
# What is Programming Language?                         ^
# How Program Works?                                    ^
# What is Python? Why, Where, When & How?               ^
  # Variables in Python                                 ^
    # What is variable                                  ^
    # Criteria to declare a variable                    ^
    # when to use variable                              ^
  # Data-Types in Python                                ^
    # primitive - int, float, boolean, null, string     ^
    # non-primitive - List, Tuple, Set, Dict
  # Operators in Python
    # Arithmatic Operation - +, -, *, /, //, **, %
    # Assigment Operation  - =, +=, -+, *=, /=, //=, **=
    # Comparison Operation - <, >, <=, >=, ==, !=
    # Logical Operation    - and, or, not
    # Membership Operation - in, not in
    # Identity Operation   - is, is not
    # Bitwise Operation    - AND (&), OR (|), XOR (^)
  # Conditional Statements -
    # if / else / elif
  # Control-Flow Statement - Loops
    # - While
    # - for
  # Function in Python - (1. user-defined func | 2. pre-built func)
    # 1. Standard
    # 2. Parametric function
    # 3. Function with return keyword
    # 4. Recursion in Python
    # 5. Ad. function (Pre-Built)
    # 6. Lambda Functions

# Heading towards NumPy
# Heading toward Pandas

# %%
# To Declare a Variable we've certain criterias which are as follows -

# IoT_Sensor_Temp = 25.3
# age = True
# if age == True:
#   print("Eligible")
# else:
#   print("not Eligible")

# num1 = 10
# num2 = 20
# _3num = 30


# IoT_Sensor_Temp   -   Pascal Case
# iot_sensor_temp   -   Lower Case
# iot_Sensor_Temp   -   camel Case
# IOT_SENSOR_TEMP   -   Upper Case

# %%
# Data-types in Python - type of data is know as Data-Type
# Primitive     - int, float, bool, null, str
# Non-Primitive - list, set, dict, tuple

# org_var
# copied_var

# Copy type -
# 1. Shallow - it will duplicate the org_var variable but don't duplicate it's properties
# 2. Deep    - it will duplicate the org_var variable as well as duplicate it's properties


# org_var = 50
# copied_var = org_var
# print("org_var : ", org_var)
# print("copied_var : ", copied_var)
# copied_var += 100          # copied_var = copied_var + 100
# print("org_var : ", org_var)
# print("copied_var : ", copied_var)



# Primitive Data-Types -

# 1. int  - contains integer values
# num_var = 10
# print(num_var)
# print(type(num_var))

# 2. float - contains decimal values
# num_var = 10.0
# print(num_var)
# print(type(num_var))

# 3. Boolean - True or false
# switchPosi = True
# switchProp = True
# switchStatus = True
# switchState = False
# print(switchState)
# print(type(switchState))


# 4. String - contains group or bunch of characters wraped in a ('') or ("")
# userName = "4567Raksha5678Raj"
# print(userName)
# print(type(userName))

# %%
# Non-Pritive Data-type - list, set, tuple, dict

# List - is a well defined ordered collection of similar or different data type elements (items)
# - denoted by "[]"
# - each and every elements are separated by ","
# - all the items or values or elements are mutable (Changeable). that means we can update list at any time
# - each and every item has it's unique value or position, jisse hum kehte hai index values - (0 to n-1)
# - in List we can perform Indexing as well (Iteration on list)

# prepare a list to store the history of my BGMI Kills
# bgmi_kills = []    # empty list
# print(bgmi_kills)
# print(type(bgmi_kills))


# bgmi_kills = [10,2,6,5,85]
# print("Before Updation : ", bgmi_kills)

# changing a list using indexing
# bgmi_kills[3] = 4
# print("After Updation : ", bgmi_kills)

# indexing - it's a operation which is performed to access individual value from a list with the help of index values

# Accessing each and every elemenet using index value in a list
# lastKill = bgmi_kills[4]
# val1 = bgmi_kills[0]
# val2 = bgmi_kills[1]
# val3 = bgmi_kills[2]
# val4 = bgmi_kills[3]
# val5 = bgmi_kills[4]
# print(val1)
# print(val2)
# print(val3)
# print(val4)
# print(val5)


# checking the data types and how len method works
# print(type(bgmi_kills))
# print(len(bgmi_kills))

# %%
# Tuples in Python - is also a well-defined ordered collection of similar or different data elements
# - denoted by "()" and each and every item is separated by ","
# - immutable (not changeable) that means we can't update the tuple after declaration
# - having index values
# - indexing can be performed

# weekDays = ()         # empty tuples
# print(weekDays)
# print(type(weekDays))

# weekDays = ("Mon", "Tues", "wed", "Thurs", "Fri", "Sat")         # empty tuples
# print(weekDays)
# print(type(weekDays))


# weekDays[5] = "sun"    # using this expression we can't perform changes ya updation on tuple
# print(weekDays)



# firstDay = weekDays[5]         # indexing on tuple
# print(firstDay)



# Interview corner -
# change a tuple of cars

# carsTup = ("BMW", "Audi", "Range Rover", "Defender", "Lambo")
# print("Car tuple", carsTup)

# carLi = list(carsTup)        # type-casting performed over here
# print("Car list", carLi)

# carLi[1] = "RR"
# print("Updated Car list", carLi)

# carsTup = tuple(carLi)
# print("updated Tuple : ", carsTup)



# type - is a method to find the data type of a variable
# type-casting - is a concept
  # - is a process in which we can convert a data-type in to any data-type


# performing Type-Casting -

# num = 10
# print(type(num))

# num = float(num)
# print(type(num))

# num = int(num)
# print(type(num))

# num = str(num)
# print(type(num))

# num = bool(num)
# print(type(num))



# li = [10,20,30,50,450]
# print(type(li))

# newTup = tuple(li)
# print(type(newTup))

# newSet = set(li)
# print(type(newSet))

# newDict = dict(li)     # not able to convert a tuple, set or list into a Dictionary


# newDict = {
#     "name": "Bhavesh",
#     "Salary": "5K"
# }

# print(newDict)
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'set'>
# {'name': 'Bhavesh', 'Salary': '5K'}
