# %% [markdown]
# ### ***Pandas Certain pre-built methods***

# %%
import pandas as pd

# %%
orgDs = pd.read_csv("originalDataset.csv")
df = pd.DataFrame(orgDs)
df
# Out:
#        Scorecard        Team 1       Team 2        Winner     Margin  \
# 0        ODI # 1     Australia      England     Australia  5 wickets
# 1        ODI # 2       England    Australia       England  6 wickets
# 2        ODI # 3       England    Australia     Australia  5 wickets
# 3        ODI # 4       England    Australia       England  2 wickets
# 4        ODI # 5   New Zealand     Pakistan   New Zealand    22 runs
# ...          ...           ...          ...           ...        ...
# 3927  ODI # 3928         India  New Zealand   New Zealand  6 wickets
# 3928  ODI # 3929  South Africa   Bangladesh  South Africa   200 runs
# 3929  ODI # 3930      Pakistan    Sri Lanka      Pakistan  9 wickets
# 3930  ODI # 3931         India  New Zealand         India  6 wickets
# 3931  ODI # 3932         India  New Zealand         India     6 runs
#
#             Ground    Match Date
# 0        Melbourne   Jan 5, 1971
# 1       Manchester  Aug 24, 1972
# 2           Lord's  Aug 26, 1972
# ...

# %%
# to partially analyze or predict the data we will use two following methods -
# head()
# tail()

# df.head()
# df.head(15)

# df.tail()
# df.tail(15)
# Out:
#        Scorecard        Team 1       Team 2        Winner      Margin  \
# 3917  ODI # 3918       England  West Indies       England   9 wickets
# 3918  ODI # 3919         India    Australia         India   7 wickets
# 3919  ODI # 3920        P.N.G.     Scotland      Scotland    101 runs
# 3920  ODI # 3921        P.N.G.     Scotland        P.N.G.   5 wickets
# 3921  ODI # 3922      Pakistan    Sri Lanka      Pakistan     83 runs
# 3922  ODI # 3923  South Africa   Bangladesh  South Africa  10 wickets
# 3923  ODI # 3924      Pakistan    Sri Lanka      Pakistan     32 runs
# 3924  ODI # 3925  South Africa   Bangladesh  South Africa    104 runs
# 3925  ODI # 3926      Pakistan    Sri Lanka      Pakistan   7 wickets
# 3926  ODI # 3927      Pakistan    Sri Lanka      Pakistan   7 wickets
# 3927  ODI # 3928         India  New Zealand   New Zealand   6 wickets
# 3928  ODI # 3929  South Africa   Bangladesh  South Africa    200 runs
# ...

# %%
# if we want to target single columns than we can use indexing
# df.head(15)
# team1df = df['Team 1']
# team1df

# if we want to target multiple columns than we can use indexing
# winTable = df[['Team 1', 'Team 2', 'Winner']]
# winTable


# if we want to filter out the DataFrame than we can filter anything like this -
matches_in_abu_dhabi = df[df['Ground'] == "Abu Dhabi"]
# matches_in_abu_dhabi_count = matches_in_abu_dhabi.count()
matches_in_abu_dhabi_count = matches_in_abu_dhabi.value_counts()
# matches_in_abu_dhabi_count = len(matches_in_abu_dhabi)
matches_in_abu_dhabi_count
# matches_in_port_moresby = df[df['Ground'] == "Port Moresby"]
# matches_in_port_moresby
