# %% [markdown]
# ### ***Pandas Certain pre-built methods***

# %%
import pandas as pd

# %%
orgDs = pd.read_csv("originalDataset.csv")
df = pd.DataFrame(orgDs)
df
# Out:
#        Scorecard        Team 1       Team 2        Winner     Margin  \
# 0        ODI # 1     Australia      England     Australia  5 wickets
# 1        ODI # 2       England    Australia       England  6 wickets
# 2        ODI # 3       England    Australia     Australia  5 wickets
# 3        ODI # 4       England    Australia       England  2 wickets
# 4        ODI # 5   New Zealand     Pakistan   New Zealand    22 runs
# ...          ...           ...          ...           ...        ...
# 3927  ODI # 3928         India  New Zealand   New Zealand  6 wickets
# 3928  ODI # 3929  South Africa   Bangladesh  South Africa   200 runs
# 3929  ODI # 3930      Pakistan    Sri Lanka      Pakistan  9 wickets
# 3930  ODI # 3931         India  New Zealand         India  6 wickets
# 3931  ODI # 3932         India  New Zealand         India     6 runs
#
#             Ground    Match Date
# 0        Melbourne   Jan 5, 1971
# 1       Manchester  Aug 24, 1972
# 2           Lord's  Aug 26, 1972
# ...

# %% [markdown]
# # ***Filtering DataFrames using Pandas***

# %%
filterDf = df[df['Team 1'] == "England"]

len(filterDf)
filterDf
# Out:
#        Scorecard   Team 1       Team 2     Winner     Margin       Ground  \
# 1        ODI # 2  England    Australia    England  6 wickets   Manchester
# 2        ODI # 3  England    Australia  Australia  5 wickets       Lord's
# 3        ODI # 4  England    Australia    England  2 wickets   Birmingham
# 5        ODI # 6  England  New Zealand    England  7 wickets      Swansea
# 6        ODI # 7  England  New Zealand  no result        NaN   Manchester
# ...          ...      ...          ...        ...        ...          ...
# 3910  ODI # 3911  England  West Indies    England  7 wickets   Manchester
# 3912  ODI # 3913  England  West Indies  no result        NaN   Nottingham
# 3914  ODI # 3915  England  West Indies    England   124 runs      Bristol
# 3915  ODI # 3916  England  West Indies    England     6 runs     The Oval
# 3917  ODI # 3918  England  West Indies    England  9 wickets  Southampton
#
#         Match Date
# 1     Aug 24, 1972
# 2     Aug 26, 1972
# ...

# %%
dataSet2 = pd.read_csv("ContinousDataset.csv")
df2 = pd.DataFrame(dataSet2)
df2
# Out:
#       Unnamed: 0   Scorecard       Team 1       Team 2           Margin  \
# 0              0     ODI # 1    Australia      England  Winner2ndInning
# 1              1     ODI # 2      England    Australia  Winner2ndInning
# 2              2     ODI # 3      England    Australia  Winner2ndInning
# 3              3     ODI # 4      England    Australia  Winner2ndInning
# 4              4     ODI # 5  New Zealand     Pakistan  Winner1stInning
# ...          ...         ...          ...          ...              ...
# 7489        3747  ODI # 3931  New Zealand        India  Winner2ndInning
# 7490        3748  ODI # 3932  New Zealand        India  Winner1stInning
# 7491        3749  ODI # 3933      Namibia    Hong Kong  Winner2ndInning
# 7492        3750  ODI # 3934       U.S.A.      Bermuda  Winner2ndInning
# 7493        3749  ODI # 3935      Namibia  East Africa  Winner1stInning
#
#             Ground    Match Date       Winner Host_Country Venue_Team1  \
# ...

# %%
dataSet3 = pd.read_csv("product_data.csv")
df3 = pd.DataFrame(dataSet3)
df3
# Out:
#       product_id     category   color size  season   supplier  cost_price  \
# 0        P000001      Bottoms   Black   XL  Spring  supplierb       78.26
# 1        P000002          ???   Black    M  Summer  supplierc       39.67
# 2        P000003         Tops   Black   XL  Summer  supplierd       27.62
# 3        P000004  Accessories   White   XL  Winter  supplierb        7.43
# 4        P000005  Accessories     NaN   XL    Fall  suppliera       12.04
# ...          ...          ...     ...  ...     ...        ...         ...
# 49995    P049996      Bottoms  Yellow   XS  Winter  supplierc        6.86
# 49996    P049997  Accessories   White    S    Fall  supplierb       30.51
# 49997    P049998      Dresses   White    L  Spring  suppliera       70.61
# 49998    P049999         Tops     Red    L  Winter  suppliera       72.73
# 49999    P050000      Dresses    Blue   XL  Spring  supplierb       25.73
#
#        list_price
# 0           46.45
# 1          147.82
# 2           44.40
# ...

# %%
# df3[df3['cost_price'] > 70].count()

# df3[df3['cost_price'] > 70]
# df3[df3['list_price'] > 100]   # by this we won't be able to filter two columns

# df3[(df3['cost_price'] > 70) & (df3['list_price'] > 100)]
# Out:
#       product_id     category  color size  season   supplier  cost_price  \
# 21       P000022  Accessories  White   XS    Fall  supplierb       74.05
# 30       P000031         Tops  White   XL  Winter  supplierd       74.45
# 33       P000034      Dresses  Green   XL  Spring  supplierb       74.58
# 40       P000041      Bottoms   Blue    S  Winter  supplierd       73.33
# 55       P000056      Dresses  Black   XS    Fall  supplierc       71.00
# ...          ...          ...    ...  ...     ...        ...         ...
# 49953    P049954         Tops   Blue   XS  Spring  suppliera       79.07
# 49975    P049976      Bottoms  White   XS  Spring  supplierc       77.60
# 49982    P049983      Dresses  Black    M  Spring  suppliera       79.48
# 49983    P049984      Dresses  Green    S  Spring  suppliera       74.21
# 49987    P049988  Accessories   Blue   XL  Spring  supplierc       77.58
#
#        list_price
# 21         120.82
# 30         123.27
# 33         155.85
# ...

# %%
cp = df3[df3['cost_price'] > 70]   # let us condider each product having cost price > 70 USD, we have to apply 10% off
cp['discount_price'] = (cp['cost_price'] / 100) * 10
cp['final_price'] = cp['cost_price'] - cp['discount_price']
# dpDemo = (cp['cost_price']/100)*10
# dpDemo
cp.to_csv('dis_pro_data.csv')
# Out:
# /tmp/ipython-input-3870912181.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cp['discount_price'] = (cp['cost_price'] / 100) * 10
# /tmp/ipython-input-3870912181.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cp['final_price'] = cp['cost_price'] - cp['discount_price']
