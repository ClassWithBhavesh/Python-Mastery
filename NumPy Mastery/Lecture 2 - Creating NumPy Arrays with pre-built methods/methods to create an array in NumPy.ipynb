# %% [markdown]
# ### ***Pre-Built Methods in NumPy***

# %%
import numpy as np

# %%
# to create an array we have several methods in numpy -

# 1. np.array()
# 2. np.arange()

# arr = np.arange(2,11, 2)
# print(arr)

# _2dArr = np.arange(1, 26)
# print(_2dArr.shape)

# _2dArr = np.arange(1, 26).reshape(5,5)          # .reshape(row, column)
# print(_2dArr)
# print(_2dArr.shape)

# _2dArr = np.arange(1, 31).reshape(2, 5, 3)          # .reshape(page, row, column)
# print(_2dArr)
# print(_2dArr.shape)
# print(np.ndim(_2dArr))



# 3. .linspace()
# even_dis_arr = np.linspace(StartPoint, EndPoint, required even distributions)
# even_dis_arr = np.linspace(1, 10)     # by default - if we will not provide any 3rd argument it will provide 50 even distributions
# print(even_dis_arr)

# even_dis_arr = np.linspace(10, 30, 3)     # let us provide 3rd argument (5) - it will generate 5 even distribution of the provided range
# print(even_dis_arr)



# 4. .zeros()
# matrix = np.zeros([2, 3, 4, 5])
# matrix
# matrix.dtype

# matrix = np.zeros([2, 3, 4, 5], dtype=np.int32)
# matrix
# matrix.dtype




# 5. .ones() - np.ones([row, column])   |   np.ones([page, row, column])   |   np.ones([page, page, row, column])
# onesArr = np.ones([5,5], dtype=np.int64)
# onesArr.dtype



# 6. .full() - np.full([4, 5, 7])  -  it will provide a array of 4rows and 5columns
# fullArr = np.full([4,5], 8, dtype=np.int64)
# fullArr
# Out:
# array([[8, 8, 8, 8, 8],
#        [8, 8, 8, 8, 8],
#        [8, 8, 8, 8, 8],
#        [8, 8, 8, 8, 8]])
