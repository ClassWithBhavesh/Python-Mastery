# %% [markdown]
# ### ***Pre-Built methods to create a random array in NumPy***

# %%
import numpy as np

# %%
# to build an random array from 0 to 1 -
# kuchValue = np.random.rand(2)
# kuchValue

# to build an 2d array from 0-1
# kuchValue = np.random.rand(2,3)
# kuchValue

# to build an 2d array from 0-101
# kuchValue = np.random.rand(2,3)*101
# kuchValue

# to build an 3d array from 0-10
# _3dArray = np.random.rand(4,12,7) * 1001
# _3dArray

# performing type casting -
# newArr = np.array(_3dArray, dtype=np.int64)
# print(newArr)

# identifying size and shape of the array -
# newArr.shape
# newArr.size

# print(np.shape(newArr))
# print(np.size(newArr))



# nArr = np.random.randn(4,2) * 101
# nArr


intArr = np.random.randint(3, 8, size=[1,4,4])
intArr
# Out:
# array([[[4, 6, 4, 7],
#         [4, 6, 5, 4],
#         [5, 5, 3, 5],
#         [5, 6, 5, 6]]])
